# %%
from google.colab import drive
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
drive.mount("/content/drive", force_remount=True )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-125-ce12a885c0e6> in <module>()
# ----> 1 drive.mount("/content/drive", force_remount=True )
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     151     if _os.path.islink(mountpoint):
#     152       raise ValueError('Mountpoint must not be a symlink')
# --> 153     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
#     154       raise ValueError('Mountpoint must not already contain files')
#     155     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#
# OSError: [Errno 107] Transport endpoint is not connected: '/content/drive'

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one/men_shoes.csv', low_memory=False)
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-124-d1b17cb32306> in <module>()
# ----> 1 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one/men_shoes.csv', low_memory=False)
#       2 df.shape
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one/men_shoes.csv' does not exist: b'/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one/men_shoes.csv'

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/dw_matrix'

# %%
mean_price = np.mean( df['prices_amountmin'])
mean_price
# Out:
# 93.53952188183217

# %%
y_true = df['prices_amountmin']
y_true.shape[0]
# Out:
# 18280

# %%
y_true = df['prices_amountmin']
y_pred = [mean_price] * y_true.shape[0]

mean_absolute_error(y_true, y_pred)
# Out:
# 63.968341227870624

# %%
df['prices_amountmin'].hist(bins=100)

# %%
np.log(df['prices_amountmin'] +1).hist(bins=100)

# %%
np.log1p(df['prices_amountmin'] ).hist(bins=100)

# %%
y_true = df['prices_amountmin']
y_pred = [np.median(y_true)] * y_true.shape[0]

mean_absolute_error(y_true, y_pred)
# Out:
# 58.01120240700219

# %%
y_true = df['prices_amountmin']
price_log_mean = np.expm1( np.mean( np.log1p(y_true)))
y_pred = [price_log_mean] * y_true.shape[0]

mean_absolute_error(y_true, y_pred)
# Out:
# 58.03539547661041

# %%
df.brand.value_counts()
# Out:
# Nike                     1709
# PUMA                      574
# Ralph Lauren              524
# New Balance               361
# VANS                      356
#                          ...
# Champ                       1
# U.S. Polo Association       1
# Anarchy                     1
# Browning                    1
# Puentes Denver              1
# Name: brand, Length: 1856, dtype: int64

# %%
df['brand_cat'] = df['brand'].factorize()[0]

# %%
feats = ['brand_cat']
X = df[ feats ].values
y = df['prices_amountmin'].values

model = DecisionTreeRegressor(max_depth=5)

scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
np.mean(scores), np.std(scores)
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
def run_model(feats):
  X = df[ feats ].values
  y = df['prices_amountmin'].values

  model = DecisionTreeRegressor(max_depth=5)

  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['brand_cat'])
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
df.manufacturer.value_counts()

# %%
df['manufacturer_cat'] = df['manufacturer'].factorize()[0]

# %%
hopes = ['manufacturer_cat']
def run_model(hopes):
  X = df[ hopes ].values
  y = df['prices_amountmin'].values

  model = DecisionTreeRegressor(max_depth=5)

  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['manufacturer_cat'])
# Out:
# (-63.133649278023746, 3.394307434888982)

# %%
df.name.value_counts()

# %%
df['name_cat'] = df['name'].factorize()[0]

# %%
names = ['name_cat']
def run_model(names):
  X = df[ hopes ].values
  y = df['prices_amountmin'].values

  model = DecisionTreeRegressor(max_depth=5)

  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['names_cat'])
# Out:
# (-63.133649278023746, 3.394307434888982)

# %%
run_model(['brand_cat', 'manufacturer_cat'])
# Out:
# (-58.539304199085976, 4.311223231615449)

# %%
ls
# Out:
# data/  HelloGithub.ipynb  ignore  LICENSE  matrix_one/  README.md

# %%
cd matrix_one
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one

# %%
ls
# Out:
# 'My Drive'/

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one'

# %%
ls
# Out:
# day4.ipynb

# %%
ls
# Out:
# data/       day4.ipynb         ignore   matrix_one/
# day3.ipynb  HelloGithub.ipynb  LICENSE  README.md

# %%
# !git add matrix_one/day4.ipynb
# Out:
# fatal: pathspec 'matrix_one/day4.ipynb' did not match any files
